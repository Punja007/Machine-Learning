# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
# from sklearn.feature_selection import RFE
# from sklearn.model_selection import train_test_split
# import statsmodels.api as sm
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.preprocessing import StandardScaler
# from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor as VIF

# %%
df = pd.read_csv("Leads.csv")
# Adjust display settings to show all columns
pd.set_option('display.max_columns', None)
df.head(5)
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit            Last Activity  \
# 0                            0                   0.0  Page Visited on Website
# 1                          674                   2.5             Email Opened
# 2                         1532                   2.0             Email Opened
# 3                          305                   1.0              Unreachable
# 4                         1428                   1.0        Converted to Lead
#
#   Country           Specialization How did you hear about X Education  \
# 0     NaN                   Select                             Select
# 1   India                   Select                             Select
# 2   India  Business Administration                             Select
# 3   India    Media and Advertising                      Word Of Mouth
# 4   India                   Select                              Other
#
#   What is your current occupation  \
# 0                      Unemployed
# 1                      Unemployed
# 2                         Student
# 3                      Unemployed
# 4                      Unemployed
#
#   What matters most to you in choosing a course Search Magazine  \
# 0                       Better Career Prospects     No       No
# 1                       Better Career Prospects     No       No
# 2                       Better Career Prospects     No       No
# 3                       Better Career Prospects     No       No
# 4                       Better Career Prospects     No       No
#
#   Newspaper Article X Education Forums Newspaper Digital Advertisement  \
# 0                No                 No        No                    No
# 1                No                 No        No                    No
# 2                No                 No        No                    No
# 3                No                 No        No                    No
# 4                No                 No        No                    No
#
#   Through Recommendations Receive More Updates About Our Courses  \
# 0                      No                                     No
# 1                      No                                     No
# 2                      No                                     No
# 3                      No                                     No
# 4                      No                                     No
#
#                                   Tags      Lead Quality  \
# 0          Interested in other courses  Low in Relevance
# 1                              Ringing               NaN
# 2  Will revert after reading the email          Might be
# 3                              Ringing          Not Sure
# 4  Will revert after reading the email          Might be
#
#   Update me on Supply Chain Content Get updates on DM Content    Lead Profile  \
# 0                                No                        No          Select
# 1                                No                        No          Select
# 2                                No                        No  Potential Lead
# 3                                No                        No          Select
# 4                                No                        No          Select
#
#      City Asymmetrique Activity Index Asymmetrique Profile Index  \
# 0  Select                   02.Medium                  02.Medium
# 1  Select                   02.Medium                  02.Medium
# 2  Mumbai                   02.Medium                    01.High
# 3  Mumbai                   02.Medium                    01.High
# 4  Mumbai                   02.Medium                    01.High
#
#    Asymmetrique Activity Score  Asymmetrique Profile Score  \
# 0                         15.0                        15.0
# 1                         15.0                        15.0
# 2                         14.0                        20.0
# 3                         13.0                        17.0
# 4                         15.0                        18.0
#
#   I agree to pay the amount through cheque  \
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
#
#   A free copy of Mastering The Interview Last Notable Activity
# 0                                     No              Modified
# 1                                     No          Email Opened
# 2                                    Yes          Email Opened
# 3                                     No              Modified
# 4                                     No              Modified

# %%
df.isna().sum()/df.shape[0] * 100
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.389610
# Do Not Email                                      0.000000
# Do Not Call                                       0.000000
# Converted                                         0.000000
# TotalVisits                                       1.482684
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              1.482684
# Last Activity                                     1.114719
# Country                                          26.634199
# Specialization                                   15.562771
# How did you hear about X Education               23.885281
# What is your current occupation                  29.112554
# What matters most to you in choosing a course    29.318182
# Search                                            0.000000
# Magazine                                          0.000000
# Newspaper Article                                 0.000000
# X Education Forums                                0.000000
# Newspaper                                         0.000000
# Digital Advertisement                             0.000000
# Through Recommendations                           0.000000
# Receive More Updates About Our Courses            0.000000
# Tags                                             36.287879
# Lead Quality                                     51.590909
# Update me on Supply Chain Content                 0.000000
# Get updates on DM Content                         0.000000
# Lead Profile                                     29.318182
# City                                             15.367965
# Asymmetrique Activity Index                      45.649351
# Asymmetrique Profile Index                       45.649351
# Asymmetrique Activity Score                      45.649351
# Asymmetrique Profile Score                       45.649351
# I agree to pay the amount through cheque          0.000000
# A free copy of Mastering The Interview            0.000000
# Last Notable Activity                             0.000000
# dtype: float64

# %% [markdown]
# Null Value Treatment

# %%
df.Country.describe()
# Out:
# count      6779
# unique       38
# top       India
# freq       6492
# Name: Country, dtype: object

# %%
df.Country.fillna("India", inplace=True)

# %%
df.Specialization.describe()
# Out:
# count       7802
# unique        19
# top       Select
# freq        1942
# Name: Specialization, dtype: object

# %%
df.loc[df.Specialization == 'Select'] = "not sure yet"
df.Specialization.fillna("not sure yet", inplace=True)

# %%
df["How did you hear about X Education"].value_counts()
df.loc[df["How did you hear about X Education"] == "Select"]= "not mentioned by the lead"
df["How did you hear about X Education"].fillna("not mentioned by the lead", inplace= True)

# %%
null_df  = pd.DataFrame(df.isna().sum()/df.shape[0] * 100 )
null_df[null_df[0]>0]
# Out:
#                                                        0
# Lead Source                                     0.021645
# TotalVisits                                     0.086580
# Page Views Per Visit                            0.086580
# What is your current occupation                28.971861
# What matters most to you in choosing a course  29.177489
# Tags                                           29.220779
# Lead Quality                                   33.116883
# Lead Profile                                   29.177489
# City                                           15.346320
# Asymmetrique Activity Index                    20.638528
# Asymmetrique Profile Index                     20.638528
# Asymmetrique Activity Score                    20.638528
# Asymmetrique Profile Score                     20.638528

# %%
drp_col = ["What is your current occupation", "What matters most to you in choosing a course", "Tags", "Lead Quality", 'Lead Profile' ]
df.drop(columns=drp_col, inplace= True)

# %%
null_df  = pd.DataFrame(df.isna().sum()/df.shape[0] * 100 )
null_df[null_df[0]>0]
# Out:
#                                      0
# Lead Source                   0.021645
# TotalVisits                   0.086580
# Page Views Per Visit          0.086580
# City                         15.346320
# Asymmetrique Activity Index  20.638528
# Asymmetrique Profile Index   20.638528
# Asymmetrique Activity Score  20.638528
# Asymmetrique Profile Score   20.638528

# %%
df["Lead Source"].fillna("not mentioned by the lead", inplace=True)

# %%
df = df[~(df["TotalVisits"].isna())]

# %%
df.City.value_counts()
# Out:
# City
# not mentioned by the lead      3142
# not sure yet                   1942
# Mumbai                         1670
# Thane & Outskirts               401
# Other Cities                    276
# Other Cities of Maharashtra     217
# Other Metro Cities              138
# Tier II Cities                   28
# Select                            1
# Name: count, dtype: int64

# %%
df.City.fillna("not mentioned by the lead", inplace=True)

# %%
df["Asymmetrique Activity Index"].fillna("not mentioned by the lead", inplace=True)
df["Asymmetrique Profile Index"].fillna('not mentioned by the lead', inplace=True)
df["Asymmetrique Activity Score"].fillna("not mentioned by the lead", inplace=True)
df["Asymmetrique Profile Score"].fillna("not mentioned by the lead", inplace=True)

# %%
df.Converted.value_counts()
# Out:
# Converted
# not mentioned by the lead    3142
# 0                            3025
# not sure yet                 1942
# 1                            1123
# Name: count, dtype: int64

# %%
df.Converted = df.Converted.apply(lambda x : 0 if x!= 1 else 1)
df.Converted.value_counts()
# Out:
# Converted
# 0    8109
# 1    1123
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
#        'Do Not Email', 'Do Not Call', 'Converted', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Country', 'Specialization', 'How did you hear about X Education',
#        'Search', 'Magazine', 'Newspaper Article', 'X Education Forums',
#        'Newspaper', 'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'City', 'Asymmetrique Activity Index', 'Asymmetrique Profile Index',
#        'Asymmetrique Activity Score', 'Asymmetrique Profile Score',
#        'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
#       dtype='object')

# %%
y = ['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
       'Do Not Email', 'Do Not Call', 'TotalVisits',
       'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
       'Country', 'Specialization', 'How did you hear about X Education',
       'Search', 'Magazine', 'Newspaper Article', 'X Education Forums',
       'Newspaper', 'Digital Advertisement', 'Through Recommendations',
       'Receive More Updates About Our Courses',
       'Update me on Supply Chain Content', 'Get updates on DM Content',
       'City', 'Asymmetrique Activity Index', 'Asymmetrique Profile Index',
       'Asymmetrique Activity Score', 'Asymmetrique Profile Score',
       'I agree to pay the amount through cheque',
       'A free copy of Mastering The Interview', 'Last Notable Activity']

# %%
def check_numeric(col, edf):
    d = {}
    for j in col:
        cnt = 0
        for item in list(edf[j].values):
            try:
                int(item)
                cnt+=1
            except:
                continue
        d[j] = cnt
    return d

# %%
x = check_numeric(y, df)

# %%
df.shape
# Out:
# (9232, 32)

# %%
df["Page Views Per Visit"].value_counts()
# Out:
# Page Views Per Visit
# not mentioned by the lead    3142
# not sure yet                 1942
# 0.0                           815
# 2.0                           713
# 3.0                           620
#                              ...
# 3.2                             1
# 2.22                            1
# 6.71                            1
# 3.91                            1
# 2.83                            1
# Name: count, Length: 83, dtype: int64

# %%
def get_the_unique_strings(edf, ad):
    l = []
    ab = {}
    col = [item for item in ad.keys() if x[item]>10]
    for j in col:
        cnt = 0
        for item in list(edf[j].values):
            try:
                int(item)
            except:
                l.append(item)
        ab[j] = set(l) 
    return ab

# %%
cd = get_the_unique_strings(df,x)

# %%
def parallal_col(x):
    print(x)
    return parallal_col

# %%
def converter(x):
    if x == "not mentioned by the lead" or x == "not sure yet":
        return 0
    else:
        return float(x)

# %%
col_to_convert =  list(cd.keys())

# %%
for item in col_to_convert:
    df[item] = df[item].apply(converter)

# %%
#sns.heatmap(df.corr(), annot=True, cmap="RdYlGn")

# %%
def check_yes_no(df1, cols):
    z = []
    for col in cols:
        try:
            if "yes" in [item.lower() for item in list(df1[col].unique())] and "no" in [item.lower() for item in list(df1[col].unique())]:
                z.append(col)
            else:
                continue
        except:
            continue
    return z

# %%
def check_not_mentioned(df1, cols):
    z = []
    for col in cols:
        try:
            if "not mentioned by the lead" in [item.lower() for item in list(df1[col].unique())]:
                z.append(col)
            else:
                continue
        except:
            continue
    return z

# %%
l = check_yes_no(df, list(df.columns))

# %%
l
# Out:
# ['Do Not Email',
#  'Do Not Call',
#  'Search',
#  'Newspaper Article',
#  'X Education Forums',
#  'Digital Advertisement',
#  'Through Recommendations',
#  'A free copy of Mastering The Interview']

# %%
m = check_not_mentioned(df, list(df.columns))

# %%
df["Search"].value_counts()
# Out:
# Search
# No                           4144
# not mentioned by the lead    3142
# not sure yet                 1942
# Yes                             4
# Name: count, dtype: int64

# %%
for item in l:
    df[item] = df[item].apply(lambda x: 1 if x.lower()== "yes" else 0)

# %%
df.drop(columns=['Prospect ID', 'Lead Number'], inplace=True)

# %%
## Homework to fill this not_sure_yet with_proper information
m
# Out:
# ['Prospect ID',
#  'Lead Origin',
#  'Lead Source',
#  'Do Not Email',
#  'Do Not Call',
#  'Last Activity',
#  'Country',
#  'Specialization',
#  'How did you hear about X Education',
#  'Search',
#  'Magazine',
#  'Newspaper Article',
#  'X Education Forums',
#  'Newspaper',
#  'Digital Advertisement',
#  'Through Recommendations',
#  'Receive More Updates About Our Courses',
#  'Update me on Supply Chain Content',
#  'Get updates on DM Content',
#  'City',
#  'Asymmetrique Activity Index',
#  'Asymmetrique Profile Index',
#  'I agree to pay the amount through cheque',
#  'A free copy of Mastering The Interview',
#  'Last Notable Activity']

# %%
df["Lead Origin"] =  df["Lead Origin"].apply(lambda x: "no_lead_origin info" if x in ["not mentioned by the lead","not sure yet"] else x)

# %%
from tqdm import tqdm
y = ['Lead Origin', 'Lead Source',
       'Do Not Email', 'Do Not Call', 'TotalVisits',
       'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
       'Country', 'Specialization', 'How did you hear about X Education',
       'Search', 'Magazine', 'Newspaper Article', 'X Education Forums',
       'Newspaper', 'Digital Advertisement', 'Through Recommendations',
       'Receive More Updates About Our Courses',
       'Update me on Supply Chain Content', 'Get updates on DM Content',
       'City', 'Asymmetrique Activity Index', 'Asymmetrique Profile Index',
       'Asymmetrique Activity Score', 'Asymmetrique Profile Score',
       'I agree to pay the amount through cheque',
       'A free copy of Mastering The Interview', 'Last Notable Activity']
y = [item for item in y if item not in list(cd.keys())]
y = [item for item in y if item not in l]
for col in tqdm(y):
    x = pd.get_dummies(df[col], drop_first= True)
    df = pd.concat([df,x], axis=1)
    df.drop(columns= col, inplace=True)
# Out:
# 100%|██████████| 16/16 [00:00<00:00, 92.49it/s]

# %%
df.head(1)
# Out:
#    Do Not Email  Do Not Call  Converted  TotalVisits  \
# 0             0            0          0          0.0
#
#    Total Time Spent on Website  Page Views Per Visit  Search  \
# 0                          0.0                   0.0       0
#
#    Newspaper Article  X Education Forums  Digital Advertisement  \
# 0                  0                   0                      0
#
#    Through Recommendations  Asymmetrique Activity Score  \
# 0                        0                          0.0
#
#    Asymmetrique Profile Score  A free copy of Mastering The Interview  \
# 0                         0.0                                       0
#
#    Landing Page Submission  Lead Add Form  Lead Import  no_lead_origin info  \
# 0                    False          False        False                 True
#
#    Direct Traffic  Facebook  Google  NC_EDM  Olark Chat  Organic Search  \
# 0           False     False   False   False       False           False
#
#    Pay per Click Ads  Press_Release  Reference  Referral Sites  \
# 0              False          False      False           False
#
#    Welingak Website   bing   blog  not mentioned by the lead  not sure yet  \
# 0             False  False  False                      False          True
#
#    testone  welearnblog_Home  youtubechannel  Email Bounced  \
# 0    False             False           False          False
#
#    Email Link Clicked  Email Opened  Email Received  \
# 0               False         False           False
#
#    Form Submitted on Website  Had a Phone Conversation  \
# 0                      False                     False
#
#    Olark Chat Conversation  Page Visited on Website  Resubscribed to emails  \
# 0                    False                    False                   False
#
#    SMS Sent  Unreachable  Unsubscribed  View in browser link Clicked  \
# 0     False        False         False                         False
#
#    Visited Booth in Tradeshow  not mentioned by the lead  not sure yet  \
# 0                       False                      False          True
#
#    Australia  Bahrain  Bangladesh  Belgium  Canada  China  France  Germany  \
# 0      False    False       False    False   False  False   False    False
#
#    Ghana  Hong Kong  India  Italy  Kuwait  Liberia  Nigeria   Oman  Qatar  \
# 0  False      False  False  False   False    False    False  False  False
#
#    Saudi Arabia  Singapore  South Africa  Sweden  Switzerland  \
# 0         False      False         False   False        False
#
#    United Arab Emirates  United Kingdom  United States  \
# 0                 False           False          False
#
#    not mentioned by the lead  not sure yet  unknown  Business Administration  \
# 0                      False          True    False                    False
#
#    E-Business  E-COMMERCE  Finance Management  Healthcare Management  \
# 0       False       False               False                  False
#
#    Hospitality Management  Human Resource Management  IT Projects Management  \
# 0                   False                      False                   False
#
#    International Business  Marketing Management  Media and Advertising  \
# 0                   False                 False                  False
#
#    Operations Management  Retail Management  Rural and Agribusiness  \
# 0                  False              False                   False
#
#    Services Excellence  Supply Chain Management  Travel and Tourism  \
# 0                False                    False               False
#
#    not mentioned by the lead  not sure yet  Email  Multiple Sources  \
# 0                      False          True  False             False
#
#    Online Search  Other    SMS  Social Media  Student of SomeSchool  \
# 0          False  False  False         False                  False
#
#    Word Of Mouth  not mentioned by the lead  not sure yet  \
# 0          False                      False          True
#
#    not mentioned by the lead  not sure yet  not mentioned by the lead  \
# 0                      False          True                      False
#
#    not sure yet  not mentioned by the lead  not sure yet  \
# 0          True                      False          True
#
#    not mentioned by the lead  not sure yet  not mentioned by the lead  \
# 0                      False          True                      False
#
#    not sure yet  Other Cities  Other Cities of Maharashtra  \
# 0          True         False                        False
#
#    Other Metro Cities  Select  Thane & Outskirts  Tier II Cities  \
# 0               False   False              False           False
#
#    not mentioned by the lead  not sure yet  02.Medium  03.Low  \
# 0                      False          True      False   False
#
#    not mentioned by the lead  not sure yet  02.Medium  03.Low  \
# 0                      False          True      False   False
#
#    not mentioned by the lead  not sure yet  not mentioned by the lead  \
# 0                      False          True                      False
#
#    not sure yet  Email Link Clicked  Email Opened  Email Received  \
# 0          True               False         False           False
#
#    Form Submitted on Website  Had a Phone Conversation  Modified  \
# 0                      False                     False     False
#
#    Olark Chat Conversation  Page Visited on Website  Resubscribed to emails  \
# 0                    False                    False                   False
#
#    SMS Sent  Unreachable  Unsubscribed  not mentioned by the lead  \
# 0     False        False         False                      False
#
#    not sure yet
# 0          True

# %%
df_train, df_test = train_test_split(df, train_size=0.8, random_state=100)

# %%
y_train = df_train.pop("Converted")
y_test = df_test.pop("Converted")

# %%
numerical_values = list(cd.keys())

# %%
numerical_values = numerical_values[1:]
numerical_values
# Out:
# ['TotalVisits',
#  'Total Time Spent on Website',
#  'Page Views Per Visit',
#  'Asymmetrique Activity Score',
#  'Asymmetrique Profile Score']

# %%
scaler = MinMaxScaler()
df_train[numerical_values] = scaler.fit_transform(df_train[numerical_values])
df_test[numerical_values] = scaler.fit_transform(df_test[numerical_values])

# %%
log_reg  = LogisticRegression()
rfe = RFE(estimator = log_reg, n_features_to_select = 20)
rfe = rfe.fit(df_train, y_train)

# %%
all_columns_status = list(df_train.columns)

# %%
columns_to_choose = [all_columns_status[item] for item in range(len(all_columns_status)) if list(rfe.support_)[item]==True]

# %%
columns_to_choose
# Out:
# ['Do Not Email',
#  'Total Time Spent on Website',
#  'Page Views Per Visit',
#  'Asymmetrique Activity Score',
#  'Asymmetrique Profile Score',
#  'Lead Add Form',
#  'no_lead_origin info',
#  'Had a Phone Conversation',
#  'Resubscribed to emails',
#  'SMS',
#  'not mentioned by the lead',
#  'not mentioned by the lead',
#  'not mentioned by the lead',
#  'not mentioned by the lead',
#  '03.Low',
#  'not mentioned by the lead',
#  'not mentioned by the lead',
#  'SMS Sent',
#  'Unreachable',
#  'Unsubscribed']

# %%
X_train = df_train[columns_to_choose]
X_test = df_test[columns_to_choose]

# %%
X_train
# Out:
#       Do Not Email  Total Time Spent on Website  Page Views Per Visit  \
# 8612             0                     0.000000              0.000000
# 7288             0                     0.000000              0.000000
# 5309             0                     0.028302              0.083333
# 277              0                     0.011680              0.208333
# 8176             0                     0.000000              0.000000
# ...            ...                          ...                   ...
# 350              0                     0.000000              0.000000
# 79               0                     0.000000              0.000000
# 8047             0                     0.601527              0.125000
# 6944             0                     0.000000              0.000000
# 5648             0                     0.101527              0.333333
#
#       Asymmetrique Activity Score  Asymmetrique Profile Score  Lead Add Form  \
# 8612                     0.000000                         0.0          False
# 7288                     0.000000                         0.0          False
# 5309                     0.000000                         0.0          False
# 277                      0.833333                         0.7          False
# 8176                     0.000000                         0.0          False
# ...                           ...                         ...            ...
# 350                      0.000000                         0.0          False
# 79                       0.000000                         0.0          False
# 8047                     0.777778                         0.9          False
# 6944                     0.000000                         0.0          False
# 5648                     0.000000                         0.0          False
#
#       no_lead_origin info  Had a Phone Conversation  Had a Phone Conversation  \
# 8612                 True                     False                     False
# 7288                 True                     False                     False
# 5309                False                     False                     False
# 277                 False                     False                     False
# 8176                 True                     False                     False
# ...                   ...                       ...                       ...
# 350                  True                     False                     False
# 79                   True                     False                     False
# 8047                False                     False                     False
# 6944                 True                     False                     False
# 5648                False                     False                     False
#
#       Resubscribed to emails  Resubscribed to emails    SMS  \
# 8612                   False                   False  False
# 7288                   False                   False  False
# 5309                   False                   False  False
# 277                    False                   False  False
# 8176                   False                   False  False
# ...                      ...                     ...    ...
# 350                    False                   False  False
# 79                     False                   False  False
# 8047                   False                   False  False
# 6944                   False                   False  False
# 5648                   False                   False  False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                       True                      False
# 277                        True                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                       True                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                       True
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                       True
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                       True                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                       True                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                       True
# 277                       False                       True
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                       True
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                       True                       True
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                       True                       True
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                       True                      False
# 277                        True                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                       True                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                       True
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                       True
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                       True                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                       True                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                       True
# 277                       False                       True
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                       True
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                       True                       True
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                       True                       True
#
#       not mentioned by the lead  not mentioned by the lead  03.Low  03.Low  \
# 8612                      False                      False   False   False
# 7288                       True                       True   False   False
# 5309                      False                      False   False   False
# 277                       False                      False   False   False
# 8176                      False                      False   False   False
# ...                         ...                        ...     ...     ...
# 350                        True                       True   False   False
# 79                         True                       True   False   False
# 8047                      False                      False   False   False
# 6944                       True                       True   False   False
# 5648                      False                      False   False   False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                       True                      False
# 277                        True                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                       True                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                       True
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                       True
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                       True                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                       True                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                       True
# 277                       False                       True
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                       True
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                      False                      False
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                      False                      False
#
#       not mentioned by the lead  not mentioned by the lead  \
# 8612                      False                      False
# 7288                       True                       True
# 5309                       True                       True
# 277                       False                      False
# 8176                      False                      False
# ...                         ...                        ...
# 350                        True                       True
# 79                         True                       True
# 8047                      False                      False
# 6944                       True                       True
# 5648                       True                       True
#
#       not mentioned by the lead  not mentioned by the lead  SMS Sent  \
# 8612                      False                      False     False
# 7288                       True                       True     False
# 5309                      False                      False      True
# 277                       False                      False     False
# 8176                      False                      False     False
# ...                         ...                        ...       ...
# 350                        True                       True     False
# 79                         True                       True     False
# 8047                      False                      False     False
# 6944                       True                       True     False
# 5648                      False                      False     False
#
#       SMS Sent  Unreachable  Unreachable  Unsubscribed  Unsubscribed
# 8612     False        False        False         False         False
# 7288     False        False        False         False         False
# 5309     False        False        False         False         False
# 277      False        False        False         False         False
# 8176     False        False        False         False         False
# ...        ...          ...          ...           ...           ...
# 350      False        False        False         False         False
# 79       False        False        False         False         False
# 8047     False        False        False         False         False
# 6944     False        False        False         False         False
# 5648     False        False        False         False         False
#
# [7385 rows x 110 columns]

# %%
boolean_columns = X_train.select_dtypes(include='bool').columns
for col in boolean_columns:
    X_train[col] = X_train[col].astype(int)

# %%
boolean_columns = X_test.select_dtypes(include='bool').columns
for col in boolean_columns:
    X_test[col] = X_test[col].astype(int)

# %%
# X_train_sm = sm.add_constant(X_train)
# log_reg_model = sm.GLM(y_train, X_train_sm, family=sm.families.Binomial())
# log_reg_model = log_reg_model.fit()
# #log_reg_model.summary()

# %%
X_train_sm = sm.add_constant(X_train)
log_reg_model = LogisticRegression(penalty='l2', solver='liblinear', C=20.0)
log_reg_model.fit(X_train_sm, y_train)
# Out:
# LogisticRegression(C=20.0, solver='liblinear')

# %%
predi = log_reg_model.predict(X_train_sm)

# %%
predi
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
acc = accuracy_score(predi, y_train)
prec = precision_score(predi, y_train)

# %%
acc
# Out:
# 0.9270142180094787

# %%
prec
# Out:
# 0.6370449678800857

# %%
from sklearn.metrics import f1_score
f1s = f1_score(predi, y_train)

# %%
f1s
# Out:
# 0.688259109311741

# %%
X_test_sm = sm.add_constant(X_test)

# %%
predic = log_reg_model.predict(X_test_sm)

# %%
test_acc = accuracy_score(predic, y_test)
test_prec = precision_score(predic, y_test)

# %%
test_acc
# Out:
# 0.9350297780184083

# %%
test_prec
# Out:
# 0.6031746031746031

# %%
f1s_test = f1_score(predic, y_test)

# %%
f1s_test
# Out:
# 0.6551724137931034
