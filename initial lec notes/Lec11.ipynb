# %%
import pandas as pb

# %%
df = pb.read_csv("DMART_RAW.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                 name  \
# 0           0  Johnson's Baby Milk Cream : 100 gms
# 1           1  Johnson's Baby Milk Cream : 100 gms
# 2           2       Johnson's Baby Lotion : 500 ml
# 3           3      Johnson's Baby Powder : 400 gms
# 4           4      Johnson's Baby Shampoo : 500 ml
#
#                      short_title  price      sku_id  buying_price  \
# 0  Johnsons Baby Lotion - 100 ml  135.0  006AF57F54     81.900002
# 1  Johnsons Baby Lotion - 100 ml  135.0  006AF57F54     81.900002
# 2  Johnsons Baby Lotion - 100 ml  345.0  006AF57F54     81.900002
# 3  Johnsons Baby Lotion - 100 ml  210.0  006AF57F54     81.900002
# 4  Johnsons Baby Lotion - 100 ml  276.0  006AF57F54     81.900002
#
#    biling_price  discount  selling_price  factory_price Quantity  category_id  \
# 0     94.833333       0.0      94.833333         70.625  can_map        425.0
# 1     94.833333       0.0      94.833333         70.625  can_map        425.0
# ...

# %%
df.info() #gives column names and their data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11560 entries, 0 to 11559
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     11560 non-null  int64
#  1   name           11560 non-null  object
#  2   short_title    11560 non-null  object
#  3   price          11560 non-null  float64
#  4   sku_id         11560 non-null  object
#  5   buying_price   11560 non-null  float64
#  6   biling_price   11560 non-null  float64
#  7   discount       11560 non-null  float64
#  8   selling_price  11560 non-null  float64
#  9   factory_price  11560 non-null  float64
#  10  Quantity       11560 non-null  object
#  11  category_id    11560 non-null  float64
#  12  L1_name        11560 non-null  object
#  13  L2_name        11560 non-null  object
#  14  L3_name        11560 non-null  object
# dtypes: float64(7), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
df.describe()  #gives a detailed info about all the numeric columns
# Out:
#         Unnamed: 0         price  buying_price  biling_price      discount  \
# count  11560.00000  11560.000000  11560.000000  11560.000000  11560.000000
# mean    5779.50000    246.741047    198.122967    232.426463     10.636257
# std     3337.22889    355.590943    248.261151    279.975918     17.334158
# min        0.00000      5.000000     10.035887      8.310066      0.000000
# 25%     2889.75000     69.000000     64.338931     73.413828      0.157129
# 50%     5779.50000    136.000000    119.489998    140.000000      3.000000
# 75%     8669.25000    263.000000    221.399994    270.000000     13.161548
# max    11559.00000   6919.000000   1682.675578   1749.247253    137.500000
#
#        selling_price  factory_price   category_id
# count   11560.000000   11560.000000  11560.000000
# mean      223.126089      98.049892    676.372318
# std       272.775258     140.984415    259.408282
# min         8.264542      20.000000    165.000000
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0                                 name  \
# 0           0  Johnson's Baby Milk Cream : 100 gms
# 1           1  Johnson's Baby Milk Cream : 100 gms
# 2           2       Johnson's Baby Lotion : 500 ml
#
#                      short_title  price      sku_id  buying_price  \
# 0  Johnsons Baby Lotion - 100 ml  135.0  006AF57F54     81.900002
# 1  Johnsons Baby Lotion - 100 ml  135.0  006AF57F54     81.900002
# 2  Johnsons Baby Lotion - 100 ml  345.0  006AF57F54     81.900002
#
#    biling_price  discount  selling_price  factory_price Quantity  category_id  \
# 0     94.833333       0.0      94.833333         70.625  can_map        425.0
# 1     94.833333       0.0      94.833333         70.625  can_map        425.0
# 2     94.833333       0.0      94.833333         70.625  can_map        425.0
#
#          L1_name     L2_name          L3_name
# 0  personal care  baby needs  baby toiletries
# 1  personal care  baby needs  baby toiletries
# ...

# %%
#list of dictionaries can also be converted to tabular format using pandas

x = [{"name": "punja","age" :  18, "job" : "student"},
         {"name" : "prakash","age" : 17, "job" : "Not Working"},
         {"name" : "mantosh","age" : 28, "job" : "DL Engineer"}]

pb.DataFrame(x)  #it is user to convert a list of dictionaries into a tabular format
# Out:
#       name  age          job
# 0    punja   18      student
# 1  prakash   17  Not Working
# 2  mantosh   28  DL Engineer

# %%
df.iloc[:4, :6]
# Out:
#    Unnamed: 0                                 name  \
# 0           0  Johnson's Baby Milk Cream : 100 gms
# 1           1  Johnson's Baby Milk Cream : 100 gms
# 2           2       Johnson's Baby Lotion : 500 ml
# 3           3      Johnson's Baby Powder : 400 gms
#
#                      short_title  price      sku_id  buying_price
# 0  Johnsons Baby Lotion - 100 ml  135.0  006AF57F54     81.900002
# 1  Johnsons Baby Lotion - 100 ml  135.0  006AF57F54     81.900002
# 2  Johnsons Baby Lotion - 100 ml  345.0  006AF57F54     81.900002
# 3  Johnsons Baby Lotion - 100 ml  210.0  006AF57F54     81.900002

# %%
#item visiblity
df.loc[df.name == "Himalaya Gentle Baby Shampoo : 200 ml"]
# Out:
#        Unnamed: 0                                   name  \
# 28             28  Himalaya Gentle Baby Shampoo : 200 ml
# 915           915  Himalaya Gentle Baby Shampoo : 200 ml
# 8178         8178  Himalaya Gentle Baby Shampoo : 200 ml
# 10000       10000  Himalaya Gentle Baby Shampoo : 200 ml
# 11048       11048  Himalaya Gentle Baby Shampoo : 200 ml
#
#                                       short_title  price      sku_id  \
# 28                  Johnsons Baby Lotion - 100 ml  135.0  006AF57F54
# 915                Johnson's Baby Powder - 200 gm  135.0  1020BBDB97
# 8178        Dove Hair Fall Rescue Shampoo - 1 ltr  135.0  8AB637808E
# 10000  Colgate Plax Gentle care Mouthwash - 250ml  135.0  AEC9867B64
# 11048                    Bagsy Malone Belt - Tan   135.0  BC2786583F
#
#        buying_price  biling_price  discount  selling_price  factory_price  \
# 28        81.900002     94.833333     0.000      94.833333      70.625000
# ...

# %%
#Item assignment
df.loc[df.name == "Himalaya Gentle Baby Shampoo : 200 ml", "name"] = "name changed"

# %%
df.iloc[0:30]
# Out:
#     Unnamed: 0                                               name  \
# 0            0                                            changed
# 1            1                                            changed
# 2            2                     Johnson's Baby Lotion : 500 ml
# 3            3                    Johnson's Baby Powder : 400 gms
# 4            4                    Johnson's Baby Shampoo : 500 ml
# 5            5                    Johnson's Baby Soap : 3x150 gms
# 6            6            Johnson's Baby Top-To-Toe Bath : 500 ml
# 7            7                  Johnson's Cotton Buds : 75 Pieces
# 8            8                      Himalaya Baby Lotion : 200 ml
# 9            9                      Himalaya Baby Lotion : 400 ml
# 10          10              Himalaya Baby Care Gift Pack : 1 Unit
# 11          11   Himalaya Extra Soft & Gentle Baby Cream : 100 ml
# 12          12   Himalaya Extra Soft & Gentle Baby Cream : 200 ml
# ...
